# %%
import pandas as pd
import os
import numpy as np
from copy import deepcopy

# %%
st = pd.HDFStore(os.path.expanduser("~/all.h5"), mode='r')

# %%
metadata_df = pd.read_csv("metadata/metadata.csv",index_col=0)

# %%
feeds = {'use':'aggregate',
        'air1':'hvac',
         'clotheswasher1':'wm',
         'dishwasher1':'dw',
         'microwave1':'mw',
         'refrigerator1':'fridge',
         'oven1':'oven',
        'car1':'ec',
         'waterheater1':'wh',
         'drye1':'dr'
        }

# %%
cities = ['Austin','Houston','San Diego','Boulder']

# %%
years = {
    2014:{'start':'1-1-2014', 'end':'12-31-2014', 'start_month':1, 'end_month':12, 'months':1},
    2015:{'start':'6-1-2015', 'end':'6-10-2015', 'start_month':1, 'end_month':12, 'months':1},
    2016:{'start':'1-1-2016', 'end':'12-31-2016', 'start_month':1, 'end_month':12, 'months':1}
    }

# %%
metadata_df[metadata_df.city=='Boulder'].index
# Out:
# Int64Index([4974, 7213, 6282, 3659, 9229, 2144,  698, 1350, 1766, 2523, 2903,
#             3734, 4499, 4703, 4830, 5187, 6083, 6148, 6174, 6956, 7001, 7208,
#             8368, 9341, 9818,  879, 2196, 5648, 5954, 8676, 3353,  232,  516,
#              547, 1879, 2824, 2931, 3104, 4601, 6264, 6800, 6888, 7818, 8273,
#             8622, 8729, 8862, 9085, 9142, 9156, 9958, 5904, 8395, 4920, 5652,
#             4147, 5400, 8555],
#            dtype='int64', name=u'dataid')

# %%
r = st['/1350']['2014']
# %matplotlib inline
r.resample("15T", how='mean').plot()
# Out:
# /Users/nipunbatra/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).mean()
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
out_overall = {}
year = 2015
year_dict = years[year]
out_overall[year] = {}
to_ignore = []
for city in ['Austin']:
    print city

    city_data = metadata_df[metadata_df['city'] == city]
    city_homes = city_data.index.values.astype('int')
    out = {}
    for home in city_homes[:]:

        if home in to_ignore:
            continue
        
        try:
            data_df = st['/%d' %home][year_dict['start']:year_dict['end']]
            data_df_resampled = data_df.resample("15T").sum()
            df_res_kwh = data_df_resampled.div(1)
            df_res_kwh.index = df_res_kwh.index.dayofyear
            # Find months where we have less than 21 hours worth data and ignore those months
            day_res = data_df.resample("1T").sum()['use'].dropna()
            a = pd.value_counts(day_res.index.day)
            lt_21_hours = a[a<43].index.values

            for m in lt_21_hours:
                df_res_kwh.loc[m] = np.NAN

            temp = {}
            for feed_name, feed_value in feeds.iteritems():
                temp[feed_value] = []
                for day in range(1, 365*96):


                    try:
                        temp[feed_value].append(df_res_kwh.loc[day, feed_name])
                    except:

                        temp[feed_value].append(np.NAN)
            out[home] = np.hstack(temp.values())




        except Exception, e:
            print e, city, home
            pass
    appliances = temp.keys()
    col_headers = []
    for appliance in appliances:
        for day in range(1, 365*96):
            col_headers.append(appliance+"_"+str(day))
    df = pd.DataFrame(out).T
    df.columns = col_headers

    # Read metadata
    mdf = pd.read_csv("metadata/%s_md.csv" %city.replace(" ",""), index_col=0)
    for column in mdf.columns:
        df[column] = mdf[column]

    city = city.replace(" ","")
    out_overall[year][city] =df

    tdf = df[['aggregate_'+str(month) for month in range(1, 13)]].dropna().copy()
    full_agg = {}


    for home in df.index:
        if home in tdf.index:
            full_agg[home] = 1


        else:
            full_agg[home] = 0
# Out:
# Austin
# 'No object named /2836 in the file' Austin 2836
# 'No object named /2743 in the file' Austin 2743
# 'No object named /5323 in the file' Austin 5323
# 'No object named /8560 in the file' Austin 8560
# 'No object named /3313 in the file' Austin 3313
# 'No object named /5052 in the file' Austin 5052
# 'No object named /3936 in the file' Austin 3936
# 'No object named /1622 in the file' Austin 1622
# 'No object named /1114 in the file' Austin 1114
# 'No object named /5433 in the file' Austin 5433
# 'No object named /1101 in the file' Austin 1101
# 'No object named /3824 in the file' Austin 3824
# 'No object named /78 in the file' Austin 78
# 'No object named /5839 in the file' Austin 5839
# 'No object named /1050 in the file' Austin 1050
# 'No object named /18 in the file' Austin 18
# 'No object named /35 in the file' Austin 35
# 'No object named /964 in the file' Austin 964
# setting an array element with a sequence. Austin 1801
# 'No object named /1852 in the file' Austin 1852
# 'No object named /2345 in the file' Austin 2345
# 'No object named /2645 in the file' Austin 2645
# 'No object named /2653 in the file' Austin 2653
# 'No object named /3739 in the file' Austin 3739
# 'No object named /4228 in the file' Austin 4228
# 'No object named /4421 in the file' Austin 4421
# 'No object named /4671 in the file' Austin 4671
# 'No object named /4726 in the file' Austin 4726
# 'No object named /5193 in the file' Austin 5193
# 'No object named /6830 in the file' Austin 6830
# 'No object named /7113 in the file' Austin 7113

# %%
out
# Out:
# {22: array([ 4405.03320312,  9587.33300781,  5755.91650391, ...,            nan,
#                    nan,            nan]),
#  26: array([ 6.5333333 ,  2.2833333 ,  0.88333333, ...,         nan,
#                 nan,         nan]),
#  48: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  59: array([ 37135.08203125,  37209.78515625,  31760.        , ...,
#           2659.54980469,   3000.41674805,   1698.43334961]),
#  68: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  77: array([ 43706.3671875 ,  37362.30078125,  29753.43359375, ...,
#                     nan,             nan,             nan]),
#  86: array([  1.        ,  10.71666622,  20.36666679, ...,   0.96666664,
#           1.73333335,   1.73333335]),
#  93: array([ 1013.29998779,   959.93334961,   869.91668701, ...,     0.        ,
#             0.        ,     0.        ]),
#  94: array([   0.        ,    0.        ,    0.        , ...,  518.13336182,
#            0.73333335,  439.16668701]),
#  101: array([  2.13333344e+00,   1.51666665e+00,   8.99999976e-01, ...,
#           0.00000000e+00,   1.45303496e+04,   2.52839990e+03]),
#  114: array([   20.44999886,    29.91666603,    16.13333321, ...,    41.51666641,
#          2281.18334961,  9770.91699219]),
#  115: array([ 0.,  0.,  0., ...,  0.,  0.,  0.]),
#  121: array([ 2.5666666 ,  1.01666665,  5.5666666 , ...,         nan,
#                 nan,         nan]),
#  130: array([ 3.23333335,  0.        ,  0.        , ...,         nan,
#                 nan,         nan]),
#  135: array([ 11152.58300781,   9748.88378906,   9182.03320312, ...,
#                     nan,             nan,             nan]),
#  160: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  171: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  187: array([    0.        ,     0.        ,    14.76666641, ...,  6750.03320312,
#          2122.44995117,   311.6000061 ]),
#  222: array([ 112.1333313 ,  107.06666565,  102.6333313 , ...,           nan,
#                   nan,           nan]),
#  243: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  252: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  267: array([ 0.05      ,  1.25      ,  1.31666672, ...,         nan,
#                 nan,         nan]),
#  297: array([ 12122.98339844,  12478.8828125 ,   6847.26660156, ...,
#                     nan,             nan,             nan]),
#  347: array([ 5980.58349609,  5022.36669922,  6325.21679688, ...,            nan,
#                    nan,            nan]),
#  364: array([  95.33333588,   86.25      ,  136.3833313 , ...,           nan,
#                   nan,           nan]),
#  370: array([ 1388.40002441,  1401.76672363,  1441.4666748 , ...,            nan,
#                    nan,            nan]),
#  379: array([           nan,            nan,            nan, ...,  9883.76660156,
#             0.        ,  7110.85009766]),
#  410: array([  7.5333333 ,  10.66666698,   0.95000005, ...,          nan,
#                  nan,          nan]),
#  434: array([  1.51333332e+01,   1.59166670e+01,   1.08500004e+01, ...,
#           4.64556689e+03,   7.72466675e+02,   5.00000007e-02]),
#  436: array([  166.4833374 ,  5434.26660156,  1656.48327637, ...,            nan,
#                    nan,            nan]),
#  457: array([ 2745.86669922,  1868.38330078,  1084.5       , ...,            nan,
#                    nan,            nan]),
#  470: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  483: array([           nan,            nan,            nan, ...,     0.        ,
#          2250.15014648,  1735.13330078]),
#  484: array([ 2.3166666 ,  1.56666672,  1.01666665, ...,         nan,
#                 nan,         nan]),
#  491: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  499: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  503: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  507: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  508: array([ 1406.66662598,   889.13330078,   725.65002441, ...,            nan,
#                    nan,            nan]),
#  545: array([ 76.5       ,  64.96666718,  61.43333435, ...,          nan,
#                  nan,          nan]),
#  555: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  573: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  575: array([         nan,          nan,          nan, ...,  63.95000076,
#          85.65000153,  58.06666565]),
#  580: array([ 82.30000305,   6.48333311,  10.9333334 , ...,          nan,
#                  nan,          nan]),
#  585: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  621: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  624: array([  9.95746680e+03,   2.23321992e+04,   7.93606689e+03, ...,
#           2.40000010e+00,   1.95000005e+00,   1.18333328e+00]),
#  645: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  661: array([ 0.        ,  0.33333334,  0.        , ...,  3.68333316,
#          8.40000057,  0.15000001]),
#  668: array([  2.48333340e+01,   7.33333349e-01,   1.66666675e+00, ...,
#           0.00000000e+00,   3.16666692e-01,   2.06348340e+03]),
#  739: array([    0.        ,     0.        ,     0.        , ...,  1744.41674805,
#          1752.0333252 ,     0.        ]),
#  744: array([ 4.63333321,  0.58333337,  3.20000005, ...,         nan,
#                 nan,         nan]),
#  765: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  772: array([ 7097.63330078,  3982.05004883,  4186.20019531, ...,            nan,
#                    nan,            nan]),
#  781: array([     0.        ,      0.        ,      0.        , ...,
#          14066.20019531,   8905.53320312,   2381.06665039]),
#  861: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  871: array([  9.14133362e+02,   9.13450012e+02,   9.17799988e+02, ...,
#           4.18718311e+03,   1.77396667e+03,   3.29999995e+00]),
#  878: array([ 3228.18334961,  2444.21679688,    32.98333359, ...,            nan,
#                    nan,            nan]),
#  890: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  898: array([ 15.11666679,  13.61666679,  31.01666641, ...,          nan,
#                  nan,          nan]),
#  900: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  930: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  936: array([ 0.,  1.,  0., ...,  0.,  0.,  0.]),
#  946: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  954: array([ 3609.19995117,  2720.85009766,  1328.51672363, ...,            nan,
#                    nan,            nan]),
#  974: array([ 925.93334961,  922.40002441,  808.38336182, ...,    0.        ,
#            0.        ,    0.        ]),
#  980: array([   0.       ,  156.6166687,    0.       , ...,          nan,
#                  nan,          nan]),
#  991: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  994: array([ 0.33333334,  5.54999971,  0.11666667, ...,         nan,
#                 nan,         nan]),
#  1037: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  1069: array([ 5317.33349609,  4953.64990234,  3860.41674805, ...,            nan,
#                    nan,            nan]),
#  1086: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  1103: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  1105: array([ 3478.16674805,  2039.36669922,  1329.65002441, ...,            nan,
#                    nan,            nan]),
#  1153: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  1169: array([ 19.18333244,  29.76666641,  13.13333321, ...,   1.5333333 ,
#           0.83333337,   1.41666675]),
#  1185: array([ 39.51666641,  54.68333435,  43.58333206, ...,          nan,
#                  nan,          nan]),
#  1192: array([  134.83332825,   160.1000061 ,   166.7833252 , ...,     5.8499999 ,
#          4261.61669922,  3564.33325195]),
#  1202: array([ 12.75      ,  13.01666641,   6.83333349, ...,          nan,
#                  nan,          nan]),
#  1283: array([  0.35000002,   0.63333333,   3.7833333 , ...,   6.38333321,
#           8.63333321,  10.78333378]),
#  1310: array([ 0.2 ,  0.  ,  0.  , ...,  0.05,  0.1 ,  0.  ]),
#  1314: array([  43.51666641,   27.63333321,   35.95000076, ...,  115.3666687 ,
#          106.        ,  109.43333435]),
#  1331: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  1334: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  1354: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  1403: array([ 33.35000229,  43.54999924,  18.36666679, ...,          nan,
#                  nan,          nan]),
#  1415: array([  7.05166702e+01,   1.05900002e+02,   8.09833298e+01, ...,
#           8.26951660e+03,   8.50000024e-01,   9.49999988e-01]),
#  1463: array([ 0.        ,  0.15000001,  0.        , ...,         nan,
#                 nan,         nan]),
#  1464: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  1479: array([  419.3999939 ,  2290.19995117,    79.58333588, ...,            nan,
#                    nan,            nan]),
#  1500: array([ 0.85000002,  1.35000002,  0.05      , ...,         nan,
#                 nan,         nan]),
#  1507: array([  3.86666656e+00,   4.19999981e+00,   4.11666679e+00, ...,
#           1.09222002e+04,   3.68898340e+03,   3.68405005e+03]),
#  1508: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  1551: array([ 48.56666565,  28.56666565,  15.41666698, ...,          nan,
#                  nan,          nan]),
#  1577: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  1586: array([ 11.71666622,  18.63333321,   3.66666651, ...,          nan,
#                  nan,          nan]),
#  1589: array([  0.00000000e+00,   5.50000012e-01,   1.50000006e-01, ...,
#           2.18650000e+03,   1.13333333e+00,   5.64688330e+03]),
#  1597: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  1601: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  1617: array([  1.38333333,  55.70000076,  14.26666641, ...,          nan,
#                  nan,          nan]),
#  1632: array([ 1.13333333,  0.94999999,  0.40000001, ...,         nan,
#                 nan,         nan]),
#  1642: array([ 3.5       ,  3.98333335,  1.41666663, ...,         nan,
#                 nan,         nan]),
#  1681: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  1697: array([  1.34666662e+01,   2.02166672e+01,   1.10500000e+03, ...,
#           1.05000007e+00,   5.55221631e+03,   6.20999985e+01]),
#  1700: array([  7.69066650e+02,   8.07116638e+02,   8.00466675e+02, ...,
#           9.76534961e+03,   4.14333344e+02,   3.66666675e-01]),
#  1714: array([  969.84997559,   963.7666626 ,   968.38336182, ...,     0.        ,
#          1789.83337402,     0.        ]),
#  1718: array([ 0.        ,  0.51666665,  0.23333333, ...,         nan,
#                 nan,         nan]),
#  1782: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  1790: array([ 115.90000153,   24.71666718,  104.8666687 , ...,           nan,
#                   nan,           nan]),
#  1791: array([ 882.11663818,  879.81665039,  868.54998779, ...,           nan,
#                   nan,           nan]),
#  1792: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  1796: array([ 0.  ,  0.  ,  0.05, ...,   nan,   nan,   nan]),
#  1800: array([  2.23333335,  15.10000038,  32.71666718, ...,          nan,
#                  nan,          nan]),
#  1801: array([           nan,            nan,            nan, ...,  1776.69995117,
#           372.5       ,     0.        ]),
#  1832: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  1845: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  1854: array([ 2283.11669922,  6238.48339844,  6534.46679688, ...,            nan,
#                    nan,            nan]),
#  1889: array([ 6617.28320312,  5257.95019531,  2356.96679688, ...,            nan,
#                    nan,            nan]),
#  1947: array([ 0.        ,  0.        ,  0.        , ...,  3.9666667 ,
#          0.06666667,  2.61666656]),
#  1953: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  1994: array([ 31581.51757812,  28979.09960938,  21392.34960938, ...,
#                     nan,             nan,             nan]),
#  2004: array([  1.61666667e+00,   3.01000004e+01,   0.00000000e+00, ...,
#           7.11999969e+01,   4.34166679e+01,   3.11066675e+03]),
#  2018: array([  0.00000000e+00,   0.00000000e+00,   8.83333325e-01, ...,
#           6.46428320e+03,   6.00000024e-01,   0.00000000e+00]),
#  2034: array([  0.        ,   0.        ,   7.2166667 , ...,  26.5       ,
#          21.13333321,  25.75      ]),
#  2062: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  2072: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  2075: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  2094: array([  2.35500011e+01,   2.86833324e+01,   4.02000008e+01, ...,
#           0.00000000e+00,   7.78801660e+03,   2.33333349e+00]),
#  2129: array([ 53.20000076,  32.03333282,  18.46666718, ...,          nan,
#                  nan,          nan]),
#  2156: array([  7277.04980469,  15660.91699219,  13249.98339844, ...,
#              0.        ,   1366.45007324,   5128.21679688]),
#  2158: array([    0.        ,     0.        ,     0.        , ...,  3007.91674805,
#          2991.68334961,  4666.39990234]),
#  2171: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  2199: array([ 0.        ,  0.        ,  0.        , ...,  3.7833333 ,
#          0.64999998,  4.0666666 ]),
#  2207: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  2233: array([ 802.58331299,  760.7833252 ,  854.7333374 , ...,           nan,
#                   nan,           nan]),
#  2242: array([   778.83331299,    792.81665039,    797.54998779, ...,
#           5597.46679688,   6809.25      ,  11443.68359375]),
#  2247: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  2335: array([ 2.29999995,  3.66666651,  2.5       , ...,         nan,
#                 nan,         nan]),
#  2337: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  2360: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  2361: array([  872.11669922,   869.75      ,   879.29998779, ...,     0.        ,
#          8182.23339844,     0.        ]),
#  2365: array([ 88.        ,  86.19999695,  76.08333588, ...,          nan,
#                  nan,          nan]),
#  2366: array([ 3.5333333,  3.4000001,  3.5      , ...,        nan,        nan,
#                nan]),
#  2378: array([ 2.5333333 ,  3.0666666 ,  0.93333334, ...,         nan,
#                 nan,         nan]),
#  2401: array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           1.63278333e+03,   7.99999952e-01,   3.33333325e+00]),
#  2449: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  2458: array([ 6953.18359375,  4462.56640625,  3482.76660156, ...,            nan,
#                    nan,            nan]),
#  2461: array([ 56.06666565,  57.16666794,  43.15000153, ...,          nan,
#                  nan,          nan]),
#  2465: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  2470: array([  2.25000000e+00,   6.66666701e-02,   0.00000000e+00, ...,
#           6.60131689e+03,   7.75283325e+02,   1.69999993e+00]),
#  2472: array([ 24.45000076,   6.44999981,   2.39999986, ...,          nan,
#                  nan,          nan]),
#  2505: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  2510: array([ 10.30000019,   0.06666667,   3.01666665, ...,          nan,
#                  nan,          nan]),
#  2520: array([ 0.  ,  0.05,  0.  , ...,   nan,   nan,   nan]),
#  2532: array([  2.31666660e+00,   1.81666672e+00,   1.95000005e+00, ...,
#           6.68760010e+03,   5.97733301e+03,   1.21494995e+03]),
#  2557: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  2575: array([ 1174.84997559,   379.2333374 ,  1211.31665039, ...,    12.4333334 ,
#             1.2166667 ,     8.33333302]),
#  2638: array([  1.50000006e-01,   0.00000000e+00,   0.00000000e+00, ...,
#           2.09759985e+03,   2.54221655e+03,   3.96176660e+03]),
#  2641: array([    0.        ,     0.        ,     0.        , ...,  4641.35009766,
#           321.5166626 ,     8.10000038]),
#  2667: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  2742: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  2750: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  2751: array([   5.30000019,    5.3499999 ,  612.7333374 , ...,           nan,
#                   nan,           nan]),
#  2755: array([  2.98333335e+00,   9.03333378e+00,   5.97666664e+01, ...,
#           2.51968335e+03,   9.80466675e+02,   4.79410010e+03]),
#  2769: array([    0.        ,     0.        ,     3.2833333 , ...,  2603.98339844,
#            50.95000076,    28.33333397]),
#  2787: array([ 7.66666651,  1.75      ,  2.8499999 , ...,  9.25      ,
#          3.83333325,  5.36666679]),
#  2814: array([   58.85000229,    56.91666794,    80.83333588, ...,  2775.31665039,
#          2413.75      ,  2868.28344727]),
#  2815: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  2818: array([  0.45000002,   2.29999995,  18.23333359, ...,          nan,
#                  nan,          nan]),
#  2829: array([ 6.38333321,  0.        ,  0.        , ...,         nan,
#                 nan,         nan]),
#  2845: array([ 413.04998779,  404.2833252 ,  414.6499939 , ...,           nan,
#                   nan,           nan]),
#  2859: array([  0.00000000e+00,   2.00000003e-01,   0.00000000e+00, ...,
#           5.49000000e+02,   0.00000000e+00,   0.00000000e+00]),
#  2864: array([ 5.63333368,  0.86666667,  2.08333325, ...,         nan,
#                 nan,         nan]),
#  2873: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  2907: array([ 556.2333374 ,    0.        ,  217.58334351, ...,           nan,
#                   nan,           nan]),
#  2925: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  2945: array([ 2.9000001 ,  0.81666666,  0.53333336, ...,         nan,
#                 nan,         nan]),
#  2953: array([  1.18333328e+00,   3.28333330e+00,   1.15000010e+00, ...,
#           1.77230005e+03,   1.00000001e-01,   1.66666672e-01]),
#  2965: array([          nan,           nan,           nan, ...,  396.83334351,
#          430.91665649,  393.3999939 ]),
#  2974: array([ 886.09997559,  921.13330078,  889.18334961, ...,           nan,
#                   nan,           nan]),
#  2980: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  2986: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  2992: array([ 12.69999981,   7.5666666 ,   9.16666698, ...,          nan,
#                  nan,          nan]),
#  2995: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3009: array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           1.09146655e+03,   4.49999988e-01,   2.66846680e+03]),
#  3032: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3036: array([  6.99999988e-01,   4.41666698e+00,   1.21333332e+01, ...,
#           6.55558350e+03,   5.77739990e+03,   0.00000000e+00]),
#  3039: array([ 876.4666748,  873.0333252,  670.7166748, ...,          nan,
#                  nan,          nan]),
#  3044: array([  1.20666666e+01,   2.21666670e+00,   2.00000003e-01, ...,
#           1.91499996e+01,   1.59206665e+03,   6.17511670e+03]),
#  3126: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3134: array([ 0.,  0.,  0., ...,  0.,  0.,  0.]),
#  3143: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3160: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3192: array([ 25456.65039062,  22977.51757812,  14807.81640625, ...,
#                     nan,             nan,             nan]),
#  3215: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3224: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3235: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3268: array([ 1.70000005,  1.04999995,  1.66666675, ...,         nan,
#                 nan,         nan]),
#  3273: array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           1.00000001e-01,   5.00000007e-02,   2.17389990e+03]),
#  3299: array([ 1.26666677,  2.35000014,  2.06666684, ...,         nan,
#                 nan,         nan]),
#  3310: array([  2.04999995e+00,   3.75000000e+00,   0.00000000e+00, ...,
#           1.14999998e+00,   3.76566650e+03,   1.57380005e+03]),
#  3367: array([  4.68666687e+01,   3.78333321e+01,   1.96666660e+01, ...,
#           4.11666679e+00,   4.09521655e+03,   6.53096631e+03]),
#  3392: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3401: array([           nan,            nan,            nan, ...,  2774.16674805,
#            91.71666718,    92.83333588]),
#  3411: array([ 47.09999847,   0.        ,   0.        , ...,          nan,
#                  nan,          nan]),
#  3413: array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           1.89441663e+03,   6.33333325e-01,   1.45653333e+03]),
#  3425: array([ 6500.38330078,  6929.61669922,  7552.89990234, ...,            nan,
#                    nan,            nan]),
#  3426: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3443: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  3456: array([    0.        ,     0.        ,     0.        , ...,  3686.91674805,
#             5.20000029,  2632.08325195]),
#  3482: array([ 12.75      ,  17.58333397,  36.71666718, ...,  35.01666641,
#          33.1166687 ,  41.98333359]),
#  3500: array([ 125.41666412,  122.9833374 ,   70.76667023, ...,           nan,
#                   nan,           nan]),
#  3504: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3506: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  3510: array([ nan,  nan,  nan, ...,   0.,   0.,   0.]),
#  3519: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3527: array([  57.16666794,  113.20000458,   96.53333282, ...,           nan,
#                   nan,           nan]),
#  3531: array([ 0.        ,  0.        ,  0.55000001, ...,         nan,
#                 nan,         nan]),
#  3538: array([ 23.66666603,  54.98333359,  89.09999847, ...,          nan,
#                  nan,          nan]),
#  3544: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3577: array([ 0.        ,  0.        ,  0.06666667, ...,         nan,
#                 nan,         nan]),
#  3631: array([ 2.79999995,  1.9333334 ,  2.70000005, ...,         nan,
#                 nan,         nan]),
#  3632: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3635: array([ 4.55000019,  3.01666665,  2.8499999 , ...,         nan,
#                 nan,         nan]),
#  3649: array([ 293.4833374 ,  302.83334351,  309.5166626 , ...,    0.        ,
#            0.        ,    0.        ]),
#  3652: array([ 1.5       ,  1.61666667,  0.        , ...,         nan,
#                 nan,         nan]),
#  3676: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3678: array([ 10009.59960938,   6978.91650391,   9450.45019531, ...,
#                     nan,             nan,             nan]),
#  3719: array([ 0.86666667,  2.8499999 ,  1.25      , ...,         nan,
#                 nan,         nan]),
#  3721: array([ 4073.31665039,  1330.76672363,   382.3500061 , ...,            nan,
#                    nan,            nan]),
#  3723: array([    0.        ,     0.        ,    10.73333359, ...,  5426.61669922,
#          1299.73327637,    32.46666718]),
#  3736: array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           2.77951660e+03,   6.66666701e-02,   0.00000000e+00]),
#  3778: array([ 6.0999999 ,  9.41666698,  3.9000001 , ...,         nan,
#                 nan,         nan]),
#  3789: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3806: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3829: array([ 17607.58398438,  16823.25      ,  10079.81640625, ...,
#             75.93333435,   2293.96655273,     78.56666565]),
#  3831: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  3849: array([ 896.40002441,  892.7666626 ,  908.4833374 , ...,           nan,
#                   nan,           nan]),
#  3873: array([ 1435.80004883,  2668.43334961,  1836.2166748 , ...,            nan,
#                    nan,            nan]),
#  3883: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3886: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3893: array([ 1195.75      ,  1233.86669922,  1230.15002441, ...,  2873.96655273,
#            13.76666641,  2141.41674805]),
#  3916: array([ 0.        ,  0.        ,  0.        , ...,  1.23333335,
#          1.93333328,  0.61666667]),
#  3918: array([  9.58333397,  16.81666756,   7.1833334 , ...,          nan,
#                  nan,          nan]),
#  3935: array([  6.49999976e-01,   7.50000000e-01,   2.34333344e+01, ...,
#           3.42053345e+03,   4.40166664e+01,   4.05666656e+01]),
#  3964: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  3967: array([ 13.6833334 ,   6.91666651,   9.91666698, ...,          nan,
#                  nan,          nan]),
#  3973: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  4000: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  4022: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  4031: array([          nan,           nan,           nan, ...,    0.        ,
#            0.        ,  750.38336182]),
#  4042: array([ 1377.66674805,  1294.15002441,  2374.96655273, ...,            nan,
#                    nan,            nan]),
#  4053: array([ 4.7833333 ,  2.8166666 ,  1.86666667, ...,         nan,
#                 nan,         nan]),
#  4135: array([  4.8166666 ,  28.96666718,  19.78333282, ...,          nan,
#                  nan,          nan]),
#  4154: array([ 100.69999695,  110.53333282,   70.76667023, ...,    7.23333311,
#            3.54999995,    1.23333335]),
#  4193: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  4213: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  4220: array([  1.85709998e+03,   1.83440002e+03,   1.82743335e+03, ...,
#           0.00000000e+00,   3.33333343e-01,   1.05250830e+04]),
#  4224: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  4251: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  4296: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  4297: array([    0.        ,     0.        ,     0.        , ...,  5675.96679688,
#            13.8166666 ,     7.83333349]),
#  4298: array([ 0.05,  0.  ,  0.  , ...,   nan,   nan,   nan]),
#  4302: array([ 24.56666756,  36.16666794,  29.46666718, ...,          nan,
#                  nan,          nan]),
#  4321: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  4336: array([  5.21666670e+00,   6.42166672e+01,   6.59666672e+01, ...,
#           5.00000007e-02,   1.45333338e+01,   7.34999990e+00]),
#  4342: array([  3.66666675e-01,   1.70000005e+00,   9.00000036e-01, ...,
#           1.83333337e-01,   9.33333337e-01,   2.12590015e+03]),
#  4352: array([   62.26666641,    60.26666641,    37.28333282, ...,  2850.03344727,
#          3840.56665039,     0.        ]),
#  4357: array([           nan,            nan,            nan, ...,     0.        ,
#          6546.58349609,     0.        ]),
#  4373: array([  1.56000004e+01,   2.75000000e+00,   1.05666666e+01, ...,
#           2.31548340e+03,   4.49610010e+03,   6.43776660e+03]),
#  4375: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  4383: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  4416: array([ 2113.44995117,  2253.35009766,  2217.01660156, ...,            nan,
#                    nan,            nan]),
#  4438: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  4447: array([  3.87166484e+04,   2.60128828e+04,   2.47192168e+04, ...,
#           4.00000006e-01,   2.83333331e-01,   2.71050000e+03]),
#  4473: array([ 13.94999981,   5.48333311,   4.2166667 , ...,          nan,
#                  nan,          nan]),
#  4505: array([  2.03166676e+01,   4.16666687e-01,   1.28833332e+01, ...,
#           1.84728333e+03,   0.00000000e+00,   0.00000000e+00]),
#  4514: array([ 14.88333321,  10.60000038,  11.91666603, ...,   7.83333349,
#          11.23333263,   8.69999981]),
#  4526: array([   31.96666718,    27.66666603,    17.18333244, ...,  3653.66674805,
#          1508.7166748 ,  6752.91650391]),
#  4544: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  4575: array([ 185.6499939 ,  203.16667175,  199.80000305, ...,           nan,
#                   nan,           nan]),
#  4590: array([             nan,              nan,              nan, ...,
#           0.00000000e+00,   2.66666681e-01,   1.85775000e+03]),
#  4633: array([           nan,            nan,            nan, ...,  7287.94970703,
#          9609.96679688,   851.75      ]),
#  4641: array([ 11293.81640625,  11581.11621094,   7324.96679688, ...,
#              0.        ,      0.        ,      0.        ]),
#  4660: array([ 33.68333435,  12.63333321,   9.41666698, ...,          nan,
#                  nan,          nan]),
#  4674: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  4732: array([  6.94999981,   0.        ,  23.26666641, ...,          nan,
#                  nan,          nan]),
#  4767: array([ 111.43333435,  107.5       ,   57.40000153, ...,           nan,
#                   nan,           nan]),
#  4776: array([ 52.51666641,  42.56666565,  40.70000076, ...,          nan,
#                  nan,          nan]),
#  4800: array([ 5752.20019531,  5056.81689453,  6030.51660156, ...,            nan,
#                    nan,            nan]),
#  4856: array([ 0.36666667,  0.46666667,  0.06666667, ...,         nan,
#                 nan,         nan]),
#  4864: array([    0.        ,  1668.90002441,  3310.64990234, ...,            nan,
#                    nan,            nan]),
#  4874: array([  6.28333330e+00,   6.83333349e+00,   4.44999981e+00, ...,
#           2.09999990e+00,   4.22803320e+03,   1.00850498e+04]),
#  4910: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  4922: array([ 19145.09960938,  12880.18359375,  14177.93359375, ...,
#                     nan,             nan,             nan]),
#  4927: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  4946: array([  32.66666794,   16.06666756,   19.14999962, ...,  480.9833374 ,
#            0.91666669,    1.39999998]),
#  4957: array([  891.54998779,   903.38336182,   918.56665039, ...,  6026.58349609,
#          4083.53320312,    52.31666565]),
#  4967: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  4998: array([ 0.        ,  0.11666667,  0.23333333, ...,         nan,
#                 nan,         nan]),
#  5026: array([ 138.2666626 ,   65.65000153,   41.73333359, ...,   28.68333244,
#           34.28333282,   34.28333282]),
#  5035: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5060: array([   0.        ,    0.        ,    0.        , ...,  436.0333252 ,
#          325.41665649,  397.1499939 ]),
#  5087: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5109: array([  2.97730332e+04,   2.79375176e+04,   2.11414336e+04, ...,
#           3.00000012e-01,   2.23030005e+03,   6.58529980e+03]),
#  5129: array([  0.2       ,   0.        ,  47.29999924, ...,          nan,
#                  nan,          nan]),
#  5209: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  5218: array([ 15192.1171875 ,  11559.84960938,  14344.95703125, ...,
#                     nan,             nan,             nan]),
#  5226: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5246: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5252: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5275: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  5279: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5298: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5317: array([  8762.13378906,  30426.8671875 ,   6860.16650391, ...,
#              0.        ,   3885.5       ,    868.75      ]),
#  5356: array([ 10958.8671875 ,   6793.98339844,   7919.56689453, ...,
#                     nan,             nan,             nan]),
#  5357: array([ 46002.05078125,  47544.46484375,  36572.08203125, ...,
#                     nan,             nan,             nan]),
#  5371: array([ 0.5,  0. ,  0. , ...,  nan,  nan,  nan]),
#  5395: array([   38.86666489,    13.59999943,    45.34999847, ...,  3972.93334961,
#            14.88333321,  4678.43359375]),
#  5403: array([  9.03333378,  13.63333321,  59.68333435, ...,   0.66666669,
#           0.        ,   0.        ]),
#  5438: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5439: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5450: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5456: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5539: array([ 2225.80004883,  3816.68334961,  1766.34997559, ...,            nan,
#                    nan,            nan]),
#  5545: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  5552: array([    0.        ,  2419.55004883,  5731.23339844, ...,            nan,
#                    nan,            nan]),
#  5568: array([    0.        ,     0.        ,     0.        , ...,  3941.23339844,
#          4528.48339844,   119.90000153]),
#  5615: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5658: array([           nan,            nan,            nan, ...,    60.25      ,
#          2657.01660156,   886.36669922]),
#  5673: array([  3.25295000e+04,   2.25987676e+04,   1.61916162e+04, ...,
#           4.53648340e+03,   9.05000019e+00,   4.53639990e+03]),
#  5677: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  5718: array([ nan,  nan,  nan, ...,   0.,   0.,   0.]),
#  5728: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5738: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5746: array([ 191.1333313,  174.4833374,  152.7666626, ...,          nan,
#                  nan,          nan]),
#  5749: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5759: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5778: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  5784: array([           nan,            nan,            nan, ...,     0.        ,
#             0.        ,  2194.53344727]),
#  5785: array([   0.        ,    0.        ,    4.63333321, ...,    0.        ,
#            0.        ,  474.29998779]),
#  5786: array([ 3499.85009766,  3207.46679688,  2586.25      , ...,            nan,
#                    nan,            nan]),
#  5796: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5809: array([   18.88333321,    29.        ,    24.06666565, ...,     0.        ,
#          6477.93359375,     0.        ]),
#  5810: array([ 25.06666565,  12.55000019,  11.48333359, ...,          nan,
#                  nan,          nan]),
#  5814: array([  1.00000001e-01,   0.00000000e+00,   5.00000007e-02, ...,
#           0.00000000e+00,   2.45525000e+03,   0.00000000e+00]),
#  5817: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5874: array([ 1014.7166748 ,   991.7666626 ,   938.36663818, ...,            nan,
#                    nan,            nan]),
#  5889: array([ 996.43334961,  969.63336182,  956.0166626 , ...,           nan,
#                   nan,           nan]),
#  5892: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5921: array([    5.4000001 ,     0.        ,    24.60000038, ...,     0.        ,
#          1833.7166748 ,  2079.91650391]),
#  5944: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  5949: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  5959: array([  1.14999998,  53.53333282,  54.88333511, ...,          nan,
#                  nan,          nan]),
#  5972: array([ 0.48333335,  0.58333331,  0.9666667 , ...,         nan,
#                 nan,         nan]),
#  6012: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  6061: array([ 871.,  867.,  862., ...,   nan,   nan,   nan]),
#  6063: array([  6.16666675e-01,   0.00000000e+00,   2.70000005e+00, ...,
#           0.00000000e+00,   2.69939990e+03,   1.14537168e+04]),
#  6072: array([ 4.41666651,  5.4000001 ,  5.33333349, ...,         nan,
#                 nan,         nan]),
#  6078: array([ 3689.86669922,  4008.25      ,  2891.85009766, ...,            nan,
#                    nan,            nan]),
#  6101: array([  0.        ,   0.        ,   0.        , ...,  83.80000305,
#          81.83333588,  85.21666718]),
#  6108: array([  937.56665039,  1602.93334961,     5.48333311, ...,            nan,
#                    nan,            nan]),
#  6121: array([         nan,          nan,          nan, ...,   1.5       ,
#          24.63333321,   3.33333325]),
#  6125: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  6139: array([  1641.4666748 ,   1641.15002441,   1644.73339844, ...,
#          10261.81640625,      0.        ,   4903.54980469]),
#  6165: array([   115.06666565,    117.01667023,    111.90000153, ...,
#          14967.25      ,    743.88336182,      0.        ]),
#  6248: array([           nan,            nan,            nan, ...,     0.        ,
#          1176.69995117,  1473.41662598]),
#  6266: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  6286: array([ 4320.86669922,  6141.14990234,  5705.61669922, ...,            nan,
#                    nan,            nan]),
#  6324: array([ 4.6833334 ,  4.08333349,  9.10000038, ...,         nan,
#                 nan,         nan]),
#  6334: array([ 0.90000004,  1.29999995,  1.5       , ...,         nan,
#                 nan,         nan]),
#  6348: array([  2.14966660e+02,   2.12466675e+02,   2.13433334e+02, ...,
#           1.94050012e+03,   1.38716663e+03,   7.50000060e-01]),
#  6412: array([  898.86669922,   923.5333252 ,   940.9666748 , ...,     0.        ,
#          2725.30004883,  6610.45019531]),
#  6418: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  6423: array([  0.00000000e+00,   4.33333337e-01,   3.41666675e+00, ...,
#           7.22578320e+03,   7.99214990e+03,   3.42761670e+03]),
#  6460: array([ 1.31666672,  0.        ,  0.        , ...,         nan,
#                 nan,         nan]),
#  6498: array([ 1.39999998,  0.5       ,  2.01666665, ...,         nan,
#                 nan,         nan]),
#  6500: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  6536: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  6545: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  6578: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  6614: array([ 4.2833333 ,  2.6500001 ,  1.81666672, ...,         nan,
#                 nan,         nan]),
#  6636: array([  0.,   0.,  nan, ...,  nan,  nan,  nan]),
#  6643: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  6673: array([ 813.20001221,  822.15002441,  817.9833374 , ...,           nan,
#                   nan,           nan]),
#  6688: array([ 64.33333588,  55.25      ,  40.21666718, ...,          nan,
#                  nan,          nan]),
#  6691: array([  5.25096680e+04,   5.00932656e+04,   3.63155820e+04, ...,
#           7.50116699e+02,   2.66666675e+00,   5.00000000e+00]),
#  6692: array([ 0.05     ,  0.2      ,  2.2166667, ...,        nan,        nan,
#                nan]),
#  6730: array([  4.98333359e+00,   7.23333311e+00,   4.56666660e+00, ...,
#           4.29956641e+03,   1.33333337e+00,   9.18011621e+03]),
#  6799: array([    8.48333359,     4.61666679,    18.28333282, ...,     0.        ,
#          2804.06665039,  1773.18334961]),
#  6826: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  6836: array([  3.02999992e+01,   3.51666665e+00,   8.55000019e+00, ...,
#           3.11505005e+03,   8.13456641e+03,   3.58616675e+03]),
#  6871: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  6910: array([ 13263.91699219,  16269.79980469,   8886.03320312, ...,
#                     nan,             nan,             nan]),
#  6911: array([ 6124.01660156,  4428.23339844,  3194.18334961, ...,            nan,
#                    nan,            nan]),
#  6941: array([  1.38485000e+04,   9.66616699e+03,   8.33941699e+03, ...,
#           3.05660010e+03,   0.00000000e+00,   4.83333349e-01]),
#  6979: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  6990: array([    0.,     0.,     0., ...,  1940.,     0.,     0.]),
#  7013: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  7016: array([  207.94999695,  1388.5333252 ,   201.8833313 , ...,    17.5       ,
#             1.91666675,    22.93333435]),
#  7017: array([ 0.        ,  0.        ,  0.15000001, ...,         nan,
#                 nan,         nan]),
#  7024: array([ 13.70000076,  11.60000038,   4.36666679, ...,   0.        ,
#           0.        ,   0.        ]),
#  7030: array([ 37.96666718,  35.11666489,  59.35000229, ...,  33.66666794,
#          31.66666603,  41.04999924]),
#  7036: array([ 46.98333359,  51.34999847,  54.31666565, ...,          nan,
#                  nan,          nan]),
#  7057: array([ 0.        ,  2.81666684,  0.13333334, ...,         nan,
#                 nan,         nan]),
#  7108: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  7117: array([  0.00000000e+00,   3.83333325e-01,   5.16666710e-01, ...,
#           5.90516663e+02,   0.00000000e+00,   0.00000000e+00]),
#  7122: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  7240: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  7276: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  7287: array([ 0.46666667,  1.48333335,  0.30000001, ...,         nan,
#                 nan,         nan]),
#  7319: array([ 43.98333359,  35.54999924,  27.23333359, ...,          nan,
#                  nan,          nan]),
#  7361: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  7390: array([ 0.11666667,  0.        ,  0.        , ...,         nan,
#                 nan,         nan]),
#  7408: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  7429: array([ 3.36666679,  0.        ,  1.88333333, ...,         nan,
#                 nan,         nan]),
#  7436: array([ 0.  ,  0.05,  0.  , ...,   nan,   nan,   nan]),
#  7468: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  7491: array([  1.59066666e+02,   1.73116669e+02,   5.00000007e-02, ...,
#                      nan,              nan,              nan]),
#  7504: array([ 11.94999981,  22.11666679,  16.29999924, ...,   0.        ,
#           0.        ,   0.        ]),
#  7510: array([ 22534.56640625,  21288.75      ,  18182.91601562, ...,
#              0.        ,      0.        ,      0.        ]),
#  7512: array([ 0.        ,  6.05000019,  5.5333333 , ...,         nan,
#                 nan,         nan]),
#  7527: array([ 1.64999998,  0.9666667 ,  0.51666665, ...,         nan,
#                 nan,         nan]),
#  7531: array([   48.18333435,    45.56666565,    31.96666718, ...,  2711.33349609,
#             0.        ,  3957.29980469]),
#  7536: array([    0.        ,     0.        ,     0.        , ...,    21.71666718,
#            13.14999962,  4072.25      ]),
#  7549: array([ 2.41666675,  2.58333325,  2.4000001 , ...,  0.        ,
#          0.        ,  0.        ]),
#  7560: array([ 125.66666412,  225.09999084,  128.1166687 , ...,           nan,
#                   nan,           nan]),
#  7585: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  7587: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  7597: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  7627: array([   21.71666718,    18.36666679,    22.88333321, ...,  2033.23339844,
#          2428.43334961,  3116.36669922]),
#  7638: array([ 4159.68359375,  3230.64990234,  2287.59985352, ...,            nan,
#                    nan,            nan]),
#  7641: array([  8.00000012e-01,   6.91666651e+00,   6.49999976e-01, ...,
#           4.11883331e+02,   2.78921655e+03,   3.33730005e+03]),
#  7680: array([  3.9333334 ,  12.90000057,   0.34999999, ...,          nan,
#                  nan,          nan]),
#  7693: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  7703: array([ 11293.06640625,   9866.71679688,   6987.46679688, ...,
#                     nan,             nan,             nan]),
#  7719: array([  0.30000001,   3.33333325,  19.66666603, ...,          nan,
#                  nan,          nan]),
#  7731: array([    0.        ,     0.        ,     0.        , ...,    25.35000038,
#            21.10000038,  5371.70019531]),
#  7739: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  7741: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  7764: array([ 5.36666679,  2.9000001 ,  4.95000029, ...,         nan,
#                 nan,         nan]),
#  7767: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  7769: array([ 3.0333333 ,  0.55000001,  6.9333334 , ...,  0.        ,
#          0.        ,  0.        ]),
#  7787: array([ 1.05000007,  1.5       ,  3.4000001 , ...,  0.        ,
#          0.        ,  0.        ]),
#  7788: array([ 26434.1171875 ,  27058.984375  ,  24280.48242188, ...,
#           2015.89990234,   3571.81665039,   1799.25      ]),
#  7792: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  7793: array([ 0.,  0.,  0., ...,  0.,  0.,  0.]),
#  7800: array([ 0.        ,  0.        ,  0.06666667, ...,         nan,
#                 nan,         nan]),
#  7850: array([   31.81666756,     8.13333321,    29.64999962, ...,  6609.01660156,
#             0.        ,     0.        ]),
#  7863: array([  4.13333368e+00,   5.05000019e+00,   4.49999988e-01, ...,
#           5.43223340e+03,   2.73366675e+03,   2.14556665e+03]),
#  7866: array([  3.00000012e-01,   3.83333325e-01,   1.00000001e-01, ...,
#           1.75588342e+03,   4.00000006e-01,   7.85491650e+03]),
#  7875: array([ 21357.5       ,  25829.8828125 ,  21953.46679688, ...,
#                     nan,             nan,             nan]),
#  7881: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  7893: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  7900: array([ 846.40002441,  839.5       ,  861.2333374 , ...,           nan,
#                   nan,           nan]),
#  7901: array([  0.00000000e+00,   5.00000007e-02,   1.45000005e+00, ...,
#           3.44500008e+01,   6.06618311e+03,   6.00570020e+03]),
#  7940: array([  0.00000000e+00,   1.96666670e+00,   1.10000002e+00, ...,
#           5.30233337e+02,   0.00000000e+00,   1.34229993e+03]),
#  7951: array([ 17.20000076,  15.9333334 ,   8.35000038, ...,  21.14999962,
#          17.95000076,  12.5       ]),
#  7965: array([ 356.3833313 ,  331.81665039,  322.4833374 , ...,           nan,
#                   nan,           nan]),
#  7973: array([           nan,            nan,            nan, ...,  3599.90014648,
#          1604.0333252 ,    18.13333321]),
#  7982: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  7984: array([ 3912.75      ,  7227.03320312,     0.        , ...,            nan,
#                    nan,            nan]),
#  7989: array([  1.05086670e+03,   1.06173328e+03,   1.09178333e+03, ...,
#           2.83333361e-01,   2.83333331e-01,   3.40655005e+03]),
#  8029: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  8031: array([ nan,  nan,  nan, ...,   0.,   0.,   0.]),
#  8034: array([ 0.05,  0.1 ,  0.  , ...,   nan,   nan,   nan]),
#  8046: array([ 959.40002441,  960.75      ,  906.2833252 , ...,           nan,
#                   nan,           nan]),
#  8047: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  8059: array([         nan,          nan,          nan, ...,  23.44999886,
#          11.5666666 ,  13.86666679]),
#  8071: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  8079: array([ 1771.33337402,  1747.26672363,  1729.59997559, ...,            nan,
#                    nan,            nan]),
#  8084: array([ 863.2666626 ,  858.93334961,  840.2666626 , ...,    0.        ,
#            0.        ,    0.        ]),
#  8086: array([ 2.2166667,  0.25     ,  0.05     , ...,        nan,        nan,
#                nan]),
#  8092: array([ 5.04999971,  1.23333335,  0.73333335, ...,         nan,
#                 nan,         nan]),
#  8117: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  8122: array([ 4558.94970703,  4826.51660156,  4711.60009766, ...,            nan,
#                    nan,            nan]),
#  8142: array([  4.51666641e+00,   6.99999988e-01,   7.55000019e+00, ...,
#           8.53250000e+02,   1.63526672e+03,   3.81448340e+03]),
#  8155: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  8156: array([  0.00000000e+00,   7.83333361e-01,   4.23333311e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   2.74351660e+03]),
#  8163: array([ 5.5333333 ,  8.48333359,  8.16666698, ...,         nan,
#                 nan,         nan]),
#  8183: array([ 4229.68310547,  4499.61669922,  2990.16674805, ...,            nan,
#                    nan,            nan]),
#  8188: array([    0.        ,     0.        ,     0.        , ...,     0.        ,
#             0.        ,  4165.98339844]),
#  8197: array([ 0.        ,  0.        ,  0.16666667, ...,         nan,
#                 nan,         nan]),
#  8198: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  8236: array([ 11.35000038,   4.4333334 ,  11.23333359, ...,   0.        ,
#           0.        ,   0.        ]),
#  8243: array([  1.50000006e-01,   0.00000000e+00,   0.00000000e+00, ...,
#           3.49999994e-01,   5.29603320e+03,   0.00000000e+00]),
#  8292: array([   32.33333206,   106.8666687 ,    21.20000076, ...,  2287.46679688,
#          2389.36669922,  3093.41650391]),
#  8317: array([   22.04999924,    57.78333282,    57.78333282, ...,     0.        ,
#             0.        ,  7632.73339844]),
#  8328: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  8386: array([ 6.13333321,  3.23333335,  0.83333331, ...,         nan,
#                 nan,         nan]),
#  8419: array([ 32209.18359375,  37654.30078125,  24705.8828125 , ...,
#                     nan,             nan,             nan]),
#  8467: array([ 165.93333435,  170.6333313 ,  143.1499939 , ...,           nan,
#                   nan,           nan]),
#  8565: array([    0.        ,     0.        ,     0.        , ...,    24.58333206,
#            40.3833313 ,  6319.70019531]),
#  8589: array([    0.        ,     0.        ,     0.        , ...,  3990.01660156,
#             0.        ,  9379.15039062]),
#  8597: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  8600: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  8626: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  8645: array([ 8.73333359,  9.21666718,  0.        , ...,  0.        ,
#          0.        ,  0.        ]),
#  8669: array([ 47745.984375 ,  40290.1328125,  31168.5      , ...,            nan,
#                    nan,            nan]),
#  8730: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  8736: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  8741: array([ 1.26666665,  2.88333344,  1.4666667 , ...,         nan,
#                 nan,         nan]),
#  8767: array([  6.88166656e+01,   4.67000008e+01,   4.86666679e+01, ...,
#           2.46226660e+03,   1.83333337e+00,   4.00000000e+00]),
#  8807: array([ 0.        ,  0.11666667,  0.        , ...,         nan,
#                 nan,         nan]),
#  8829: array([  71.78333282,   88.56666565,  110.65000153, ...,           nan,
#                   nan,           nan]),
#  8848: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  8852: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  8857: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  8872: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  8890: array([ 0.25      ,  0.15000001,  0.15000001, ...,         nan,
#                 nan,         nan]),
#  8942: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  8956: array([  3.33333343e-01,   1.00000000e+00,   1.83333337e-01, ...,
#           3.09666672e+01,   1.56833334e+01,   7.37366638e+02]),
#  8961: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  8967: array([ 29.33333206,  40.34999847,  25.76666641, ...,          nan,
#                  nan,          nan]),
#  8986: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  8995: array([  5.00000000e-01,   1.10000002e+00,   2.06666660e+00, ...,
#           3.24741650e+03,   7.83333361e-01,   0.00000000e+00]),
#  9001: array([ nan,  nan,  nan, ...,   0.,   0.,   0.]),
#  9019: array([ 27.73333359,  17.68333244,  14.01666641, ...,  34.40000153,
#          66.93333435,  38.08333206]),
#  9052: array([   16.03333282,    13.14999962,    35.29999924, ...,     7.88333321,
#             8.88333321,  4644.5       ]),
#  9121: array([  5.00000000e-01,   2.33333325e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   3.70530005e+03,   0.00000000e+00]),
#  9134: array([ 1.29999995,  0.73333335,  2.0999999 , ...,  0.        ,
#          0.        ,  0.        ]),
#  9139: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  9141: array([  0.69999999,   0.15000001,  15.53333282, ...,          nan,
#                  nan,          nan]),
#  9160: array([  9.3166666 ,   9.41666698,  41.33333206, ...,          nan,
#                  nan,          nan]),
#  9165: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  9182: array([ 6782.96679688,  8812.70019531,  5738.71679688, ...,            nan,
#                    nan,            nan]),
#  9195: array([ 6749.95019531,  5233.04980469,  5715.68310547, ...,            nan,
#                    nan,            nan]),
#  9201: array([ 6746.51660156,  5893.08349609,  5349.04980469, ...,            nan,
#                    nan,            nan]),
#  9215: array([ 12.5       ,   8.73333359,  19.25      , ...,          nan,
#                  nan,          nan]),
#  9233: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  9235: array([ nan,  nan,  nan, ...,   0.,   0.,   0.]),
#  9237: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  9248: array([   95.73332977,    67.68333435,    21.61666679, ...,  2290.98339844,
#          5803.75      ,     6.70000029]),
#  9251: array([ 5007.48339844,  7028.85009766,  3758.64990234, ...,            nan,
#                    nan,            nan]),
#  9278: array([ 38312.6484375 ,  33484.984375  ,  24473.58398438, ...,
#           8538.81640625,   2817.21655273,    712.9833374 ]),
#  9295: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  9333: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  9340: array([  107.34999847,  8732.91699219,  4758.29980469, ...,            nan,
#                    nan,            nan]),
#  9343: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  9356: array([ 11524.20019531,   3677.08325195,   3754.15014648, ...,
#           5389.81689453,   1571.48327637,   7659.64990234]),
#  9434: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  9451: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  9484: array([  143.2166748 ,   142.83332825,   128.8500061 , ...,  5347.01660156,
#          7085.31640625,    58.93333435]),
#  9498: array([ 3916.46679688,  3888.25      ,  3096.98339844, ...,            nan,
#                    nan,            nan]),
#  9499: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  9509: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  9578: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  9609: array([ 0.        ,  0.        ,  4.05000019, ...,         nan,
#                 nan,         nan]),
#  9610: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  9613: array([  0.00000000e+00,   0.00000000e+00,   3.49999994e-01, ...,
#           0.00000000e+00,   0.00000000e+00,   3.53413330e+03]),
#  9624: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  9631: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  9643: array([            nan,             nan,             nan, ...,
#              0.        ,  10909.98339844,   3581.21679688]),
#  9647: array([ 1744.40002441,  1748.31665039,  1731.65002441, ...,            nan,
#                    nan,            nan]),
#  9654: array([ 0.        ,  0.        ,  0.        , ...,  3.33333325,
#          1.6833334 ,  3.6500001 ]),
#  9670: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  9674: array([ 9399.1171875 ,  5806.06640625,  9965.41699219, ...,            nan,
#                    nan,            nan]),
#  9701: array([  5.68333340e+00,   2.48333335e+00,   4.66666698e-01, ...,
#           3.09999990e+00,   2.26471655e+03,   3.76666665e+00]),
#  9729: array([ 0.30000001,  0.75      ,  0.61666667, ...,  3.4333334 ,
#          2.7833333 ,  2.64999986]),
#  9737: array([  4.26666689e+00,   9.75000000e+00,   1.85000002e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   2.82473340e+03]),
#  9745: array([ 65.03333282,  63.78333282,  62.06666565, ...,          nan,
#                  nan,          nan]),
#  9766: array([   77.91666412,    39.70000076,    53.01666641, ...,  4989.        ,
#          4879.71679688,   659.89996338]),
#  9771: array([  7.81999969e+01,   6.48000031e+01,   3.07833347e+01, ...,
#           1.78898340e+03,   1.48318335e+03,   5.00000007e-02]),
#  9773: array([ 106.1166687 ,  103.33333588,   88.66666412, ...,           nan,
#                   nan,           nan]),
#  9803: array([ 4945.05029297,   990.06665039,  2279.63330078, ...,            nan,
#                    nan,            nan]),
#  9830: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  9846: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  9875: array([ 0.66666663,  0.        ,  0.05      , ...,         nan,
#                 nan,         nan]),
#  9912: array([ 4.3166666 ,  1.9000001 ,  2.76666665, ...,  0.28333333,
#          0.05      ,  0.56666666]),
#  9915: array([   12.3166666 ,    11.61666679,     7.30000019, ...,     0.        ,
#           261.1333313 ,  3378.36669922]),
#  9919: array([ 6.19999981,  6.0666666 ,  0.80000001, ...,         nan,
#                 nan,         nan]),
#  9921: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  9922: array([   29.53333282,    22.33333397,    10.        , ...,     0.        ,
#          8086.06640625,     0.        ]),
#  9923: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  9926: array([    0.        ,     0.        ,     0.        , ...,  3849.76660156,
#             6.5999999 ,    10.61666679]),
#  9929: array([  5.6500001 ,  17.26666641,   6.9666667 , ...,          nan,
#                  nan,          nan]),
#  9931: array([  0.,   0.,   0., ...,  nan,  nan,  nan]),
#  9932: array([ 319.2666626 ,  313.0166626 ,  298.66665649, ...,           nan,
#                   nan,           nan]),
#  9933: array([  1.01333332e+01,   0.00000000e+00,   0.00000000e+00, ...,
#           1.31771670e+04,   3.22296655e+03,   3.50975000e+03]),
#  9934: array([  3.66456836e+04,   4.27348672e+04,   3.92386016e+04, ...,
#           2.15000010e+00,   1.16666663e+00,   1.88333333e+00]),
#  9935: array([ 45975.484375  ,  46948.6328125 ,  25465.43359375, ...,
#              0.        ,      0.        ,      0.        ]),
#  9936: array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#  9937: array([ 0.55000001,  0.        ,  0.43333334, ...,         nan,
#                 nan,         nan]),
#  9938: array([  96.16666412,   97.68333435,  102.48332977, ...,           nan,
#                   nan,           nan]),
#  9939: array([ 249.43333435,  222.18333435,  164.9833374 , ...,           nan,
#                   nan,           nan]),
#  9942: array([ 26.08333397,  23.86666679,  16.51666641, ...,          nan,
#                  nan,          nan]),
#  9971: array([ 30254.69921875,  28601.08398438,  19907.01757812, ...,
#                     nan,             nan,             nan]),
#  9981: array([ 5634.63330078,  5384.78320312,  5739.        , ...,            nan,
#                    nan,            nan]),
#  9982: array([     0.        ,      0.        ,      0.        , ...,
#              0.        ,  14160.79980469,   2559.28320312])}

# %%
def remove_lt(out_overall):
    for region in ['Austin']:
    #for region in ['SanDiego','Austin']:
        for year in [2015]:
        #for year in [2014, 2015, 2016]:
            df = out_overall[year][region]
            to_remove_agg_lt_appliance = []
            for appliance in ['hvac','wm','dw','mw','fridge','oven']:
                for month in range(1, 13):
                    a=df.query('aggregate_%d<1.35*%s_%d' %(month, appliance, month))
                    if len(a):
                        for x in a.index.values:
                            if x not in to_remove_agg_lt_appliance:
                                to_remove_agg_lt_appliance.append(x)
            print to_remove_agg_lt_appliance, year, region
            out_overall[year][region] = out_overall[year][region].drop(to_remove_agg_lt_appliance)
            
    return out_overall

# %%
out_overall = remove_lt(out_overall)
# Out:
# [1069, 7638] 2015 Austin

# %% [markdown]
# ### Removing outliers based on aggregate
#
# 1. Remove high energy using z-score test

# %%
def is_outlier(points, thresh=3.5):
    """
    Returns a boolean array with True if points are outliers and False 
    otherwise.

    Parameters:
    -----------
        points : An numobservations by numdimensions array of observations
        thresh : The modified z-score to use as a threshold. Observations with
            a modified z-score (based on the median absolute deviation) greater
            than this value will be classified as outliers.

    Returns:
    --------
        mask : A numobservations-length boolean array.

    References:
    ----------
        Boris Iglewicz and David Hoaglin (1993), "Volume 16: How to Detect and
        Handle Outliers", The ASQC Basic References in Quality Control:
        Statistical Techniques, Edward F. Mykytka, Ph.D., Editor. 
    """
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)

    modified_z_score = 0.6745 * diff / med_abs_deviation

    return modified_z_score > thresh

# %%
out_overall[2015]['Austin'].isnull().sum().sum()
# Out:
# 1330566L

# %%
df['%s_%d' %(appliance, month)].dropna()
# Out:
# 59       7012.250000
# 86       4969.333496
# 93          0.000000
# 94        118.666664
# 101      5014.183594
# 115         0.000000
# 121     12029.866211
# 130      1267.349976
# 187      4896.083496
# 267      4726.200195
# 364         5.383333
# 370        19.200001
# 410      5810.867188
# 434      8305.433594
# 507         0.000000
# 624         5.900000
# 661         0.333333
# 668      2286.683350
# 739         0.000000
# 781      3500.199951
# 871      7008.816406
# 974     19434.833984
# 1037     3928.733398
# 1169        1.800000
# 1185     1954.066650
# 1192       44.750000
# 1283        0.100000
# 1310     7834.816895
# 1314       91.566666
# 1415     2476.800049
#             ...
# 8645     4249.349609
# 8767        0.550000
# 8848     2849.016846
# 8956       15.283334
# 8995     3157.800049
# 9019     2865.133301
# 9052        8.166667
# 9134        0.000000
# 9215     1201.633301
# 9248    10408.849609
# 9278      741.533325
# 9295     3084.466797
# 9356      262.149994
# 9484        1.233333
# 9578        0.066667
# 9613      786.366638
# 9654        7.600000
# 9701        0.100000
# 9737      582.599976
# 9745       49.133335
# 9766     7618.000000
# 9771     2538.866699
# 9912        0.216667
# 9915        0.000000
# 9922        0.000000
# 9926        4.583333
# 9933       35.433334
# 9934        2.216667
# 9935        0.000000
# 9982        0.000000
# Name: dr_12, Length: 214, dtype: float64

# %%
appliance, month = 'oven', 1
d = out_overall[2014]['Austin']['%s_%d' %(appliance, month)].dropna()
drop_outlier = d.index[is_outlier(d, thresh=5)].values
drop_outlier

# %%
d.ix[drop_outlier]

# %%
from copy import deepcopy
ooc = deepcopy(out_overall)

# %%
out_overall =deepcopy(ooc)

# %%
APPLIANCES_ORDER = ['aggregate', 'hvac', 'fridge', 'mw', 'dw', 'wm', 'oven']
year = 2014
to_remove = {}
for region in ['Austin','SanDiego']:
    to_remove[region] = {}
    for year in [2014, 2015, 2016]:
        to_remove[region][year] = {}
        f = out_overall[year][region].copy()
        for appliance in APPLIANCES_ORDER :
            to_remove[region][year][appliance] = []

            for month in range(1, 13):


                # Dropping outlier
                d = f['%s_%d' %(appliance, month)].dropna()
                drop_outlier = d.index[is_outlier(d, thresh=5)].values
                for x in drop_outlier:
                    to_remove[region][year][appliance].append((x, month))

                    f = f.set_value(x, '%s_%d' %(appliance, month),np.NAN)
        out_overall[year][region]=f

# %%
# Setting for missing data
def set_nan(home , months, year=2014, region='Austin'):
    for appliance in APPLIANCES_ORDER:
        for month in months:
            out_overall[year][region] = out_overall[year][region].set_value(home, '%s_%d' %(appliance, month), np.NaN)

# %%
set_nan(2378, [5, 6, 7])
set_nan(4297, [6, 7])
set_nan(8086, [5, 6, 7, 8, 9])
set_nan(7017, [7, 8, 9])
set_nan(6941, [8])
set_nan(527, range(1, 13))

# %%
out_overall[2014]['Austin'].get_value(2378, 'wm_5')

# %%
f.loc[x, '%s_%d' %(appliance, month)]

# %%
out_overall[2014]['Austin']['oven_1'].dropna()

# %%
import pickle

# %%
pickle.dump(out_overall, open('metadata/daily.pkl','w'))

# %%
out_overall[year][region].loc[x,'%s_%d' %(appliance, month)]

# %%
out_overall[2014]['Austin'].loc[9745,'%s_%d' %('oven', 1)]

# %%
out_overall[2015]['Austin']
